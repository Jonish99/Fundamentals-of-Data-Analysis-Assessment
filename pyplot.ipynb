# %% [markdown]
# ## A demonstration of matplotlib.pyplot package
#
# Author: Jon Ishaque
#
# Commenced: 29th September 2021
#
# GMIT SID: G00398244
#
# Documentation (https://matplotlib.org/)
#
# 1. Matplot lib an overview
#
# "Matplotlib is a comprehensive library for creating static, animated, and interactive visualizations in Python. Matplotlib makes easy things easy and hard things possible." (Matplotlib — Visualization with Python, 2021)

# %%
#plotting
import matplotlib.pyplot as plt 
import numpy as np

# %% [markdown]
# In its simplist form, the plot method take arrays as paramenter, and take a range of each array and use it as an axis and plot the values.
# Even one array will take the range for both axes and make a proportional plot.
#
# This plot take two arrays and makes a plot, the default plot style is b-, or blue line, in this case I have subsituted blue line for red line

# %%
plt.plot([1, 2, 3, 4],[7,8,9,10],'r-')

# %% [markdown]
# There are various line styles that can be used on plots as well as line.
# Colours are denoted by letter,
# the following default colors are available: (colors — Matplotlib 1.4.2 documentation, 2021)
#     b: blue.
#
# g: green.
#
# r: red.
#
# c: cyan.
#
# m: magenta.
#
# y: yellow.
#
# k: black.
#
# w: white.
#
# The matplotlib.colors offers a suite of methods which can map numbers to imported palletes. #see example below!!!!!!!!!!!!!!!!!
# Additional plots can also format the shape of lines or plotted coordinates:
#
# '--' dashes
#
# 's'  squares
#
# '^'  trianle up
#
# '>'  triangle right
#
# ','  pixel
#
# '.'  dot
# to name a few (matplotlib.markers — Matplotlib 3.5.0 documentation, 2021).
#
#
# The plot below is adapted code from (Pyplot tutorial — Matplotlib 3.5.0 documentation, 2021)

# %%
x = np.arange(0., 5., 0.2) #array of 0 - 5 at .2 interals
print(x)
# green dashes - linear plot
# cayan right trianges cubic plot
# yellow up trianger quaratic plot
plt.plot(x, x, 'g--', x, x**2, 'c<', x, x**3, 'y^')
plt.show()
# Out:
# [0.  0.2 0.4 0.6 0.8 1.  1.2 1.4 1.6 1.8 2.  2.2 2.4 2.6 2.8 3.  3.2 3.4
#  3.6 3.8 4.  4.2 4.4 4.6 4.8]

# %% [markdown]
# Graphs in Matplotlib are drawn on *figures* which can contain one or more axes.
# The figure acts as a *container* for 'child' axes which includes *artists* such as the title, legend and the canvas (not too relevant to matplot users)(Usage Guide — Matplotlib 3.5.0 documentation, 2021). In pyplot, axes refers to the axis which create a plot space usually two but sometimes three in 3D plots, i.e a plot. A figure will contain at least one axes but may also contain multiple axes. A subplot is one of the axes on a mulit-axes figure. Is configured with a tuple defining the grid layout. For example, subplot(2,3) will produce a grid with 3 rows each able to contain a plot. The location of an axes on any position in the grid is controled via an array value passed to the grid, for example, ax[0,2].plot(x) will place the axes in the 1st row from the top and 3rd column from the left of the grid.
#
# Illustration representing the Matplotlib object hierarchy(Python, 2021)
# <img src="fig_map.bc8c7cabd823.png" width =200 style="vertical-align:middle" alt="Illustration representing the Matplotlib object hierarchy(Python, 2021)">
#
# Axis are the lines usually seen as the y and x axis which numbers are shown, delimited by the upper and lower boundaries of the array passed. The pyplot axis properties included numbers, and ticks and subtics  - the subdivisions dividing numbers. The location of ticks is controlled by the locator object and the tick labels by the formatter, (Usage Guide — Matplotlib 3.5.0 documentation, 2021)
#
# All objects in the figure are known as artists.
#
# The following plot is adapted from a range of soureces to demonstrate many of the figure properties

# %%
# (How To Display A Plot In Python using Matplotlib - ActiveState, 2021)

fig, ax = plt.subplots()
line1, = ax.plot([1,2,3], label="Line 1", linestyle='--')
line2, = ax.plot([3, 2, 1], label="Line 2", linewidth=4)

# Create a legend. The legend is reference to line on the plotas the axes in added to the variable line1 above. handles=[line1]
legend1 = ax.legend(handles=[line1], loc='upper right')
#Legend a can be added manually, eg Legend 1
# Add the legend manually to the Axes.
ax.add_artist(legend1)
#Or as in the case of this legend added directly to the axes.
ax.legend(handles=[line2], loc='lower right')
#need to add ticks, titles, legend handlers and more
plt.rcParams["figure.figsize"] = [7.50, 3.50]#Users can also control the size of the figure
#rather than show all the ticks on an axis the MaxLocator method allows users to control the number of ticks on any axis
#(VanderPlas, 2021)
ax.xaxis.set_major_locator(plt.MaxNLocator(3)) 
ax.yaxis.set_major_locator(plt.MaxNLocator(6)) 

plt.show()

# %% [markdown]
# In this example adapted (VanderPlas, 2021) from  we look at how we can create tick labels

# %%
# Plot a sine and cosine curve
fig, ax = plt.subplots()
x = np.linspace(0, 3 * np.pi, 1000) # create a sequence of 1000 numbers between 0 and 3 * pi for the x axis
#plot 1
ax.plot(x, np.sin(x), lw=3, label='Sine') # use the sine of x for the y axis on subplot
#plot 2
ax.plot(x, np.cos(x), lw=3, label='Cosine')# use consine of x for the y axis on subplot.

# Set up grid, legend, and limits
ax.grid(True) #create a grid
ax.legend(frameon=False)
ax.axis('equal')#
ax.set_xlim(0, 3 * np.pi)# ensure the x axis starts at 0 and finishes at 3 * pi, 
#in this case it means the lines extend to the edge of the plot, i.e the x axis has the same range as the values on x.

#set the major and minor tics at user determined values
ax.xaxis.set_major_locator(plt.MultipleLocator(np.pi / 2))#half values of pi
ax.xaxis.set_minor_locator(plt.MultipleLocator(np.pi / 4))#quarter values of pi

#The following code is from VanderPlas, 2021

#Now to custom label the ticks.
#Use  Matplotlib's LaTeX support - allowing the printing of mathetmatical symbols, i.e. pi
def format_func(value, tick_number):
    # find values on the pi/2
    N = int(np.round(2 * value / np.pi))
    if N == 0:
        return "0" #1st value is 0
    elif N == 1:
        return r"$\pi/2$" #2nd value is pi/2
    elif N == 2:
        return r"$\pi$" #3rd value is pi
    elif N % 2 > 0: # for the remaining values on the odd value-3, (even position -4) e.g 3*pi/2
        return r"${0}\pi/2$".format(N) 
    else:
        return r"${0}\pi$".format(N // 2) #the even value * pi
#use the function to set the ticks labels.
#The plt funcformatter takes a function to create the tick labels
ax.xaxis.set_major_formatter(plt.FuncFormatter(format_func))

# %%
# Create a Figure with 2 rows and 2 columns of subplots: 
#using axes
#adapted from: (How To Display A Plot In Python using Matplotlib - ActiveState, 2021)
fig, ax = plt.subplots(2, 2)
#linspace created sequence of 100 evenly spaced number between 0 and 100
x = np.linspace(0, 5, 100)
#print (x)
# Index 4 Axes arrays in 4 subplots within 1 Figure: 
ax[0, 0].plot(x, np.sin(x), 'g') #row=0, column=0
ax[1, 0].plot(range(100), 'b') #row=1, column=0
ax[0, 1].plot(x, np.cos(x), 'r') #row=0, column=1
ax[1, 1].plot(x, np.tan(x), 'c') #row=1, column=1

plt.show()

# %% [markdown]
# ### Three interesting plots

# %%
#(An easy introduction to 3D plotting with Matplotlib, 2021)


fig = plt.figure()
ax = plt.axes(projection="3d")

z_line = np.linspace(0, 15, 1000)
x_line = np.cos(z_line)
y_line = np.sin(z_line)
ax.plot3D(x_line, y_line, z_line, 'gray')

z_points = 15 * np.random.random(100)
x_points = np.cos(z_points) + 0.1 * np.random.randn(100)
y_points = np.sin(z_points) + 0.1 * np.random.randn(100)
ax.scatter3D(x_points, y_points, z_points, c=z_points, cmap='hsv');
plt.rcParams["figure.figsize"] = [10, 10]#Users can also control the size of the figure
plt.show()

# %%
x = np.arange(0.0,10.0,0.01)
y = 3.0 * x +1.0

noise = np.random.normal(0.10,1.0,len(x))

plt.plot(x,y + noise,'c.', label="noise" )
plt.plot(x,y,'g.', label="strt" )
plt.title("Simple plot")
plt.xlabel('weight')
plt.ylabel('mass')
plt.legend()

plt.show()

# %%
x = np.arange(0.0,10.0,0.01)
y = 3.0 * x +1.0

noise = np.random.normal(0.10,1.0,len(x))
#repeat calls to the plot
plt.plot(x,y + noise,'r.' )
plt.plot(x,y,'b.')

plt.show()
#close plot, then new plot
plt.plot(x,y + noise,'c.' )
plt.plot(x,y,'g.')

plt.show()

# %%
x=np.random.normal(0.0,1.0,1000)

#histogram plot creates bins n the range
plt.hist(x, bins =25)
plt.show()

# %%
x = np.arange(1.0,10.0,0.1)

plt.plot(x, x**2,'g-',label="x^2")
plt.plot(x, x**3,'b-',label="x^3")
plt.plot(x, x**4,'r-',label="x^4")
plt.plot(x, x**5,'k-',label="x^x")

plt.legend()
plt.show()

# %%
x = np.random.uniform(0.0,10.0,100)
y = np.random.uniform(0.0,100.0,100)
z = np.random.normal(100.0,40.0,100)
c = np.random.randint(0,100,100)

plt.scatter(x,y,c=c,s=z)

plt.show()
# Out:
# C:\Users\jonishaque\Anaconda3\lib\site-packages\matplotlib\collections.py:922: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %%
#one row two cols
plt.subplot(1,2,1)

x=np.random.normal(0.0,1.0,1000)
plt.hist(x)

plt.subplot(2,2,2)
x=np.random.uniform(-3.0,3.0,1000)
plt.hist(x)
pl


plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-3175f7a4bc5c> in <module>
#       7 plt.subplot(2,2,2)
#       8 x=np.random.uniform(-3.0,3.0,1000)
# ----> 9 plt.hist(x,x,x)
#      10
#      11
#
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, data, **kwargs)
#    2683         orientation='vertical', rwidth=None, log=False, color=None,
#    2684         label=None, stacked=False, *, data=None, **kwargs):
# -> 2685     return gca().hist(
#    2686         x, bins=bins, range=range, density=density, weights=weights,
#    2687         cumulative=cumulative, bottom=bottom, histtype=histtype,
#
# ~\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1445     def inner(ax, *args, data=None, **kwargs):
#    1446         if data is None:
# -> 1447             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1448
#    1449         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    6649             # this will automatically overwrite bins,
#    6650             # so that each histogram uses the same bins
# -> 6651             m, bins = np.histogram(x[i], bins, weights=w[i], **hist_kwargs)
#    6652             tops.append(m)
#    6653         tops = np.array(tops, float)  # causes problems later if it's an int
#
# <__array_function__ internals> in histogram(*args, **kwargs)
#
# ~\Anaconda3\lib\site-packages\numpy\lib\histograms.py in histogram(a, bins, range, normed, weights, density)
#     790     a, weights = _ravel_and_check_weights(a, weights)
#     791
# --> 792     bin_edges, uniform_bins = _get_bin_edges(a, bins, range, weights)
#     793
#     794     # Histogram is an integer or a float array depending on the weights.
#
# ~\Anaconda3\lib\site-packages\numpy\lib\histograms.py in _get_bin_edges(a, bins, range, weights)
#     429         bin_edges = np.asarray(bins)
#     430         if np.any(bin_edges[:-1] > bin_edges[1:]):
# --> 431             raise ValueError(
#     432                 '`bins` must increase monotonically, when an array')
#     433
#
# ValueError: `bins` must increase monotonically, when an array

# %%
https://hub.mybinder.turing.ac.uk/user/matplotlib-mpl-brochure-binder-advb5unp/doc/tree/MatplotlibExample.ipynb
    #time series exaple
    
https://matplotlib.org/stable/plot_types/arrays/contour.html#sphx-glr-plot-types-arrays-contour-py
   #examples of static, animated,  

https://jakevdp.github.io/PythonDataScienceHandbook/04.06-customizing-legends.html

# %%
#seaborn sits on matplolib

# %% [markdown]
# ---
# ## References:
#
#
# ActiveState. 2021. How To Display A Plot In Python using Matplotlib - ActiveState. [online] Available at: <https://www.activestate.com/resources/quick-reads/how-to-display-a-plot-in-python/> [Accessed 23 November 2021].
#
# Het.as.utexas.edu. 2021. colors — Matplotlib 1.4.2 documentation. [online] Available at: <https://het.as.utexas.edu/HET/Software/Matplotlib/api/colors_api.html> [Accessed 23 November 2021].
#
# Matplotlib.org. 2021. Matplotlib — Visualization with Python. [online] Available at: <https://matplotlib.org/> [Accessed 23 November 2021].
#
# Matplotlib.org. 2021. matplotlib.markers — Matplotlib 3.5.0 documentation. [online] Available at: <https://matplotlib.org/stable/api/markers_api.html> [Accessed 23 November 2021].
#
# Medium. 2021. An easy introduction to 3D plotting with Matplotlib. [online] Available at: <https://towardsdatascience.com/an-easy-introduction-to-3d-plotting-with-matplotlib-801561999725> [Accessed 6 December 2021].
#
# Python, R., 2021. Python Plotting With Matplotlib (Guide) – Real Python. [online] Realpython.com. Available at: <https://realpython.com/python-matplotlib-guide/> [Accessed 6 December 2021].
#
# VanderPlas, J., 2021. Customizing Ticks | Python Data Science Handbook. [online] Jakevdp.github.io. Available at: <https://jakevdp.github.io/PythonDataScienceHandbook/04.10-customizing-ticks.html> [Accessed 6 December 2021].

# %% [markdown]
# ### End
